# %% [markdown]
# # Basic EDA

# %%
# Import libraries
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import sys

sys.path.append("..")
from src.utils import get_metadata
from src.preprocess import BoneProcessor

# %% [markdown]
# ## Data load

# %%
# Set image paths
BASE_PATH = Path("base/path/here")
IMAGES_PATH = BASE_PATH / "images_3d"
METADATA_PATH = BASE_PATH / "train.csv"

# %%
# Load metadata file
metadata_df = get_metadata(METADATA_PATH, IMAGES_PATH)

metadata_df

# %%
processor = BoneProcessor(
    metadata_df, output_dir="2_5D_images8bit", bit_depth=8, window=(2000, 500)
)
processor.process_files()
# Out:
# 0it [00:00, ?it/s]

# %%
image = cv2.imread(
    "2_5D_images8bit/151ea4c19b_slice_x0_y0_gp_133.png", cv2.IMREAD_UNCHANGED
)

# %%
image.max()
# Out:
# 255

# %%
plt.imshow(image[:, :, 0], cmap="bone")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
plt.imshow(image[:, :, 1], cmap="bone")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
plt.imshow(image[:, :, 2], cmap="bone")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
plt.imshow(image)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)
